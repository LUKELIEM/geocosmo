# %% [markdown]
# Cosmetecor MultiElectrode EMF Dataset
# ==================
#
# Multi-electrode ground measurement technique was introduced by Docent D. Kuznetsov in the 1980s as an earthquake prediction method. There are currently several stations collecting EMF data using the Kuznetsov's technique. These data are archived in an FTP site:
# <ftp://cosmetecor.org/archive_all/>
#
# This Notebook contains the production code for
# * Automatically extracting .LOG files from the FTP site
# * Gluing these .LOG files into yearly .csv files
# * Creating a HDF5 file with the years as the groups, and timestamp and EMF as datasets under these groups

# %%
# As usual, a bit of setup

import time, os, json
import numpy as np
import matplotlib.pyplot as plt
import csv
import h5py
import sys

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 6.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## FTP File Extraction
#
# The data collected at each station is archived in folders "/archive_all/YEAR/STATION_NAME/" at the FTP site. The files are a mix of .LOG and .7Z files (.7Z files can be decompressed into .LOG files using Winzip).
#
# For each station, the download should generate XXXX .LOG files (each representing 1 day of data). Each .LOG file has 86400 rows of data (24hr x 60min x 60sec). Each row consists of:
# (1) Datetime
# (2) 32 measurements

# %%
import ftplib

#Open ftp connection
ftp = ftplib.FTP('ftp.cosmetecor.org', 'anonymous','luke8liem@gmail.com')


# ftp_dirs = ["/archive_all/2013/S1-IMFSET/",
#             "/archive_all/2014/S1-IMFSET/",
#             "/archive_all/2015/S1-IMFSET_2015/",
#             "/archive_all/2016/S1-IMFSET_2016/",
#             "/archive_all/2017/S1-IMFSET_2017/"]
# local_dir = "cosmetecor data/s1-imfset/"

#ftp_dirs = ["/archive_all/2012/s1-DESP-PK/",
#            "/archive_all/2013/s1-DESP-PK/",
#            "/archive_all/2014/s1-DESP-PK/",
#            "/archive_all/2015/s1-DESP-PK_2015/",
#            "/archive_all/2016/s1-DESP-PK_2016/",
#            "/archive_all/2017/s1-DESP-PK_2017/"]
#local_dir = "cosmetecor data/s1-DESP-PK/"

#ftp_dirs = ["/archive_all/2012/s1-DESP-UZ/",
#            "/archive_all/2013/s1-DESP-UZ/",
#            "/archive_all/2014/s1-DESP-UZ/",
#            "/archive_all/2015/s1-DESP-UZ_2015/",
#            "/archive_all/2016/s1-DESP-UZ_2016/",
#            "/archive_all/2017/s1-DESP-UZ_2017/"]
#local_dir = "cosmetecor data/s1-DESP-UZ/"

# ftp_dirs = ["/archive_all/2012/s2-imfset/",
#            "/archive_all/2013/s2-imfset/",
#            "/archive_all/2014/s2-imfset/",
#            "/archive_all/2015/s2-imfset_2015/",
#           "/archive_all/2016/s2-imfset_2016/",
#           "/archive_all/2017/s2-imfset_2017/"]
# local_dir = "cosmetecor data/s2-imfset/"

#ftp_dirs = ["/archive_all/2012/s3-imfset/",
#            "/archive_all/2013/s3-imfset/",
#            "/archive_all/2014/s3-imfset/",
#            "/archive_all/2015/s3-imfset_2015/",
#            "/archive_all/2016/s3-imfset_2016/",
#            "/archive_all/2017/s3-imfset_2017/"]
#local_dir = "cosmetecor data/s3-imfset/"

#ftp_dirs = ["/archive_all/2012/s4-esso/",
#            "/archive_all/2013/s4-esso/",
#            "/archive_all/2014/s4-esso/",
#            "/archive_all/2015/s4-esso_2015/",
#            "/archive_all/2016/s4-esso_2016/"]
#local_dir = "D:/geocosmo/cosmetecor data/s4-esso/"

#ftp_dirs = ["/archive_all/2013/s5-altai/",
#            "/archive_all/2014/s5-altai/",
#            "/archive_all/2015/s5-altai_2015/",
#            "/archive_all/2016/s5-altai_2016/",
#            "/archive_all/2017/s5-altai_2017/"]
#local_dir = "D:/geocosmo/cosmetecor data/s5-altai/"

#ftp_dirs = ["/archive_all/2013/s7-imfset/",
#            "/archive_all/2014/s7-imfset/",
#            "/archive_all/2015/s7-imfset_2015/",
#            "/archive_all/2016/s7-imfset_2016/",
#            "/archive_all/2017/s7-imfset_2017/"]
#local_dir = "cosmetecor data/s7-imfset/"

#ftp_dirs = ["/archive_all/2014/s8-imfset/",
#            "/archive_all/2015/s8-imfset_2015/",
#            "/archive_all/2016/s8-imfset_2016/",
#            "/archive_all/2017/s8-imfset_2017/"]
#local_dir = "D:/geocosmo/cosmetecor data/s8-imfset/"

#ftp_dirs = ["/archive_all/2015/s9-imfset_2015/",
#            "/archive_all/2016/s9-imfset_2016/",
#            "/archive_all/2017/s9-imfset_2017/"]
#local_dir = "D:/geocosmo/cosmetecor data/s9-imfset/"

ftp_dirs = ["/archive_all/2016/s10-imfset_2016/",
            "/archive_all/2017/s10-imfset_2017/"]
local_dir = "D:/geocosmo/cosmetecor data/s10-imfset/"

for ftp_dir in ftp_dirs:
    ftp.cwd(ftp_dir)

    # Generate a list of files names in the current directory
    files = []

    try:
        files = ftp.nlst()
    except ftplib.error_perm, resp:
        if str(resp) == "550 No files found":
            print "No files in this directory"
        else:
            raise

    # Extract all the files in the current directory into a local folder        
    for f in files:
        command = "RETR "+ f   # RETR Filename
        destination = local_dir+f
        print "Extracting %s" % f
        dFile = open(destination, "wb")
        ftp.retrbinary(command, dFile.write)
        dFile.close()               
   
ftp.quit()
# Out:
# Extracting s10-tula-160729.7z
# Extracting s10-tula-160730.7z
# Extracting s10-tula-160731.7z
# Extracting s10-tula-160801.7z
# Extracting s10-tula-160802.7z
# Extracting s10-tula-160803.7z
# Extracting s10-tula-160804.7z
# Extracting s10-tula-160805.7z
# Extracting s10-tula-160806.7z
# Extracting s10-tula-160807.7z
# Extracting s10-tula-160808.7z
# Extracting s10-tula-160809.7z
# Extracting s10-tula-160810.7z
# Extracting s10-tula-160811.7z
# Extracting s10-tula-160812.7z
# Extracting s10-tula-160813.7z
# Extracting s10-tula-160814.7z
# Extracting s10-tula-160815.7z
# Extracting s10-tula-160816.7z
# Extracting s10-tula-160817.7z
# Extracting s10-tula-160818.7z
# Extracting s10-tula-160819.7z
# Extracting s10-tula-160820.7z
# Extracting s10-tula-160821.7z
# Extracting s10-tula-160822.7z
# Extracting s10-tula-160823.7z
# Extracting s10-tula-160824.7z
# Extracting s10-tula-160825.7z
# Extracting s10-tula-160826.7z
# Extracting s10-tula-160827.7z
# Extracting s10-tula-160828.7z
# Extracting s10-tula-160829.7z
# Extracting s10-tula-160830.7z
# Extracting s10-tula-160831.7z
# Extracting s10-tula-160901.7z
# Extracting s10-tula-160902.7z
# Extracting s10-tula-160903.7z
# Extracting s10-tula-160904.7z
# Extracting s10-tula-160905.7z
# Extracting s10-tula-160906.7z
# Extracting s10-tula-160907.7z
# Extracting s10-tula-160908.7z
# Extracting s10-tula-160909.7z
# Extracting s10-tula-160910.7z
# Extracting s10-tula-160912.7z
# Extracting s10-tula-160913.7z
# Extracting s10-tula-160914.7z
# Extracting s10-tula-160915.7z
# Extracting s10-tula-160916.7z
# Extracting s10-tula-160917.7z
# Extracting s10-tula-160918.7z
# Extracting s10-tula-160920.7z
# Extracting s10-tula-160921.7z
# Extracting s10-tula-160922.7z
# Extracting s10-tula-160923.7z
# Extracting s10-tula-160924.7z
# Extracting s10-tula-160925.7z
# Extracting s10-tula-160926.7z
# Extracting s10-tula-160927.7z
# Extracting s10-tula-160928.7z
# Extracting s10-tula-160929.7z
# Extracting s10-tula-160930.7z
# Extracting s10-tula-161001.7z
# Extracting s10-tula-161002.7z
# Extracting s10-tula-161003.7z
# Extracting s10-tula-161004.7z
# Extracting s10-tula-161005.7z
# Extracting s10-tula-161006.7z
# Extracting s10-tula-161007.7z
# Extracting s10-tula-161008.7z
# Extracting s10-tula-161009.7z
# Extracting s10-tula-161010.7z
# Extracting s10-tula-161011.7z
# Extracting s10-tula-161012.7z
# Extracting s10-tula-161013.7z
# Extracting s10-tula-161014.7z
# Extracting s10-tula-161015.7z
# Extracting s10-tula-161016.7z
# Extracting s10-tula-161017.7z
# Extracting s10-tula-161018.7z
# Extracting s10-tula-161019.7z
# Extracting s10-tula-161020.7z
# Extracting s10-tula-161021.7z
# Extracting s10-tula-161029.7z
# Extracting s10-tula-161030.7z
# Extracting s10-tula-161031.7z
# Extracting s10-tula-161101.7z
# Extracting s10-tula-161102.7z
# Extracting s10-tula-161103.7z
# Extracting s10-tula-161104.7z
# Extracting s10-tula-161105.7z
# Extracting s10-tula-161106.7z
# Extracting s10-tula-161107.7z
# Extracting s10-tula-161108.7z
# Extracting s10-tula-161109.7z
# Extracting s10-tula-161110.7z
# Extracting s10-tula-161111.7z
# Extracting s10-tula-161112.7z
# Extracting s10-tula-161113.7z
# Extracting s10-tula-161114.7z
# Extracting s10-tula-161115.7z
# Extracting s10-tula-161116.7z
# Extracting s10-tula-161117.7z
# Extracting s10-tula-161118.7z
# Extracting s10-tula-161119.7z
# Extracting s10-tula-161120.7z
# Extracting s10-tula-161121.7z
# Extracting s10-tula-161122.7z
# Extracting s10-tula-161123.7z
# Extracting s10-tula-161124.7z
# Extracting s10-tula-161125.7z
# Extracting s10-tula-161126.7z
# Extracting s10-tula-161127.7z
# Extracting s10-tula-161128.7z
# Extracting s10-tula-161129.7z
# Extracting s10-tula-161130.7z
# Extracting s10-tula-161201.7z
# Extracting s10-tula-161210.7z
# Extracting s10-tula-161211.7z
# Extracting s10-tula-161212.7z
# Extracting s10-tula-161213.7z
# Extracting s10-tula-161214.7z
# Extracting s10-tula-161215.7z
# Extracting s10-tula-161216.7z
# Extracting s10-tula-161217.7z
# Extracting s10-tula-161218.7z
# Extracting s10-tula-161219.7z
# Extracting s10-tula-161220.7z
# Extracting s10-tula-161221.7z
# Extracting s10-tula-161222.7z
# Extracting s10-tula-161223.7z
# Extracting s10-tula-161224.7z
# Extracting s10-tula-161225.7z
# Extracting s10-tula-161226.7z
# Extracting s10-tula-161227.7z
# Extracting s10-tula-161228.7z
# Extracting s10-tula-161229.7z
# Extracting s10-tula-161230.7z
# Extracting s10-tula-161231.7z
# Extracting s10-tula-170101.7z
# Extracting s10-tula-170102.7z
# Extracting s10-tula-170103.7z
# Extracting s10-tula-170104.7z
# Extracting s10-tula-170105.7z
# Extracting s10-tula-170116.7z
# Extracting s10-tula-170117.7z
# Extracting s10-tula-170118.7z
# Extracting s10-tula-170119.7z
# Extracting s10-tula-170120.7z
# Extracting s10-tula-170121.7z
# Extracting s10-tula-170122.7z
# Extracting s10-tula-170123.7z
# Extracting s10-tula-170124.7z
# Extracting s10-tula-170125.7z
# Extracting s10-tula-170126.7z
# Extracting s10-tula-170127.7z
# Extracting s10-tula-170128.7z
# Extracting s10-tula-170129.7z
# Extracting s10-tula-170130.7z
# Extracting s10-tula-170131.7z
# Extracting s10-tula-170201.7z
# Extracting s10-tula-170202.7z
# Extracting s10-tula-170203.7z
# Extracting s10-tula-170204.7z
# Extracting s10-tula-170205.7z
# Extracting s10-tula-170206.7z
# Extracting s10-tula-170207.7z
# Extracting s10-tula-170208.7z
# Extracting s10-tula-170209.7z
# Extracting s10-tula-170210.7z
# Extracting s10-tula-170211.7z
# Extracting s10-tula-170212.7z
# Extracting s10-tula-170213.7z
# Extracting s10-tula-170214.7z
# Extracting s10-tula-170215.7z
# Extracting s10-tula-170216.7z
# Extracting s10-tula-170217.7z
# Extracting s10-tula-170218.7z
# Extracting s10-tula-170219.7z
# Extracting s10-tula-170220.7z
# Extracting s10-tula-170221.7z
# Extracting s10-tula-170222.7z
# Extracting s10-tula-170223.7z
# Extracting s10-tula-170224.7z
# Extracting s10-tula-170225.7z
# Extracting s10-tula-170226.7z
# Extracting s10-tula-170227.7z
# Extracting s10-tula-170228.7z
# Extracting s10-tula-170301.7z
# Extracting s10-tula-170302.7z
# Extracting s10-tula-170303.7z
# Extracting s10-tula-170304.7z
# Extracting s10-tula-170305.7z
# Extracting s10-tula-170306.7z
# Extracting s10-tula-170307.7z
# Extracting s10-tula-170308.7z
# Extracting s10-tula-170309.7z
# Extracting s10-tula-170310.7z
# Extracting s10-tula-170311.7z
# Extracting s10-tula-170312.7z
# Extracting s10-tula-170313.7z
# Extracting s10-tula-170314.7z
# Extracting s10-tula-170315.7z
# Extracting s10-tula-170316.7z
# Extracting s10-tula-170317.7z
# Extracting s10-tula-170318.7z
# Extracting s10-tula-170319.7z
# Extracting s10-tula-170320.7z
# Extracting s10-tula-170321.7z
# Extracting s10-tula-170322.7z
# Extracting s10-tula-170323.7z
# Extracting s10-tula-170324.7z
# Extracting s10-tula-170325.7z
# Extracting s10-tula-170326.7z
# Extracting s10-tula-170327.7z
# Extracting s10-tula-170328.7z
# Extracting s10-tula-170329.7z
# Extracting s10-tula-170330.7z
# Extracting s10-tula-170331.7z
# Extracting s10-tula-170401.7z
# Extracting s10-tula-170402.7z
# Extracting s10-tula-170403.7z
# Extracting s10-tula-170404.7z
# Extracting s10-tula-170405.7z
# Extracting s10-tula-170406.7z
# Extracting s10-tula-170407.7z
# Extracting s10-tula-170408.7z
# Extracting s10-tula-170409.7z
# Extracting s10-tula-170410.7z
# Extracting s10-tula-170411.7z
# Extracting s10-tula-170412.7z
# Extracting s10-tula-170413.7z
# Extracting s10-tula-170414.7z
# Extracting s10-tula-170415.7z
# Extracting s10-tula-170416.7z
# Extracting s10-tula-170417.7z
# Extracting s10-tula-170418.7z
# Extracting s10-tula-170419.7z
# Extracting s10-tula-170420.7z
# Extracting s10-tula-170421.7z
# Extracting s10-tula-170422.7z
# Extracting s10-tula-170423.7z
# Extracting s10-tula-170424.7z
# Extracting s10-tula-170425.7z
# Extracting s10-tula-170426.7z
# Extracting s10-tula-170427.7z
# Extracting s10-tula-170428.7z
# Extracting s10-tula-170429.7z
# Extracting s10-tula-170430.7z
# Extracting s10-tula-170501.7z
# Extracting s10-tula-170502.7z
# Extracting s10-tula-170503.7z
# Extracting s10-tula-170504.7z
# Extracting s10-tula-170505.7z
# Extracting s10-tula-170506.7z
# Extracting s10-tula-170507.7z
# Extracting s10-tula-170508.7z
# Extracting s10-tula-170509.7z
# Extracting s10-tula-170510.7z
# Extracting s10-tula-170511.7z
# Extracting s10-tula-170512.7z
# Extracting s10-tula-170513.7z
# Extracting s10-tula-170514.7z
# Extracting s10-tula-170515.7z
# Extracting s10-tula-170516.7z
# Extracting s10-tula-170517.7z
# Extracting s10-tula-170518.7z
# Extracting s10-tula-170519.7z
# Extracting s10-tula-170520.7z
# Extracting s10-tula-170521.7z
# Extracting s10-tula-170522.7z
# Extracting s10-tula-170523.7z
# Extracting s10-tula-170524.7z
# Extracting s10-tula-170525.7z
# Extracting s10-tula-170526.7z
# Extracting s10-tula-170527.7z
# Extracting s10-tula-170528.7z
# Extracting s10-tula-170529.7z
# Extracting s10-tula-170530.7z
# Extracting s10-tula-170531.7z
# Extracting s10-tula-170601.7z
# Extracting s10-tula-170602.7z
# Extracting s10-tula-170603.7z
# Extracting s10-tula-170604.7z
# Extracting s10-tula-170605.7z
# Extracting s10-tula-170606.7z
# Extracting s10-tula-170607.7z
# '221 Goodbye.'

# %% [markdown]
# ## Consolidate Daily .LOG files --> Annual .csv File
#
# Using the code below, daily .LOG files can be consolidated into yearly .csv files. As an example, for the Station 6 Chieti dataset, the following will be generated:
#
# * s6-chieti2017.csv
# * s6-chieti2016.csv
# * s6-chieti2015.csv
# * s6-chieti2014.csv
# * s6-chieti2013.csv

# %%
import h5py
from data_util.data_analyze import *
import glob
import csv

# s1-imfset parameters
# years = ["13","14","15","16","17"]
# csv_filename_header = 's1-imfset20'
# log_filename_header = 'cosmetecor data\s1-imfset\S1-ELISOVO-'

#s1-desp-pk parameters
#years = ["12","13","14","15","16","17"]
#csv_filename_header = 's1-desp-pk20'
#log_filename_header = 'cosmetecor data\s1-DESP-PK\DESP-'

# s1-desp-uz parameters
#years = ["12","13","14","15","16","17"]
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s1-desp-uz20'
#log_filename_header = 'D:/geocosmo/cosmetecor data/s1-DESP-UZ\DESP-UZ-'

# s2-imfset parameters
# years = ["12","13","14","15","16","17"]
# csv_filename_header = 's2-imfset20'
# log_filename_header = 'cosmetecor data\s2-imfset\IFPET-'

# s3-imfset parameters
#years = ["12","13","14","15","16","17"]
#csv_filename_header = 's3-imfset20'
#log_filename_header = 'cosmetecor data\s3-imfset\S3-OKEAN-'

# s4-esso parameters
#years = ["12","13","14","15","16"]
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s4-esso20'
#log_filename_header = 'D:/geocosmo/cosmetecor data/s4-esso\S4-ESSO-'

#s5-altai parameters
#years = ["13","14","15","16","17"]
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s5-altai20'
#log_filename_header = 'D:/geocosmo/cosmetecor data/s5-altai\S5-ALTAI-'

# s6-chieti parameters
# years = ["12","13","14","15","16","17"]
# csv_filename_header = 's6-chieti20'
# log_filename_header = 'cosmetecor data\s6-chieti\S6-CHIETI-'

# s7-imfset parameters
#years = ["13","14","15","16","17"]
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s7-imfset20'
#log_filename_header = 'D:/geocosmo/cosmetecor data/s7-imfset\S7-OKEAN-'

# s8-imfset parameters
#years = ["14","15","16","17"]
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s8-imfset20'
#log_filename_header = 'D:/geocosmo/cosmetecor data/s8-imfset\S8-IMFSET-'

# s9-imfset parameters
#years = ["15","16","17"]
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s9-imfset20'
#log_filename_header = 'D:/geocosmo/cosmetecor data/s9-imfset\S9-IMFSET-'

# s10-imfset parameters
years = ["16","17"]
csv_filename_header = 'D:/geocosmo/cosmetecor data/s10-imfset20'
log_filename_header = 'D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-'

for year in years:
    csv_filename = csv_filename_header+year+'.csv'
    print csv_filename

    fout = open(csv_filename,'a')

    i = 0
    extraction_criteria = log_filename_header+year+'*.LOG'
    for filename in glob.glob(extraction_criteria):
        print filename
        for line in open(filename,'r'):
            fout.write(line)   
             
    fout.close()
# Out:
# D:/geocosmo/cosmetecor data/s10-imfset2016.csv
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160729.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160730.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160731.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160801.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160802.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160803.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160804.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160805.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160806.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160807.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160808.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160809.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160810.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160811.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160812.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160813.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160814.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160815.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160816.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160817.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160818.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160819.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160820.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160821.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160822.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160823.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160824.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160825.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160826.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160827.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160828.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160829.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160830.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160831.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160901.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160902.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160903.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160904.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160905.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160906.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160907.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160908.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160909.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160910.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160912.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160913.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160914.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160915.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160916.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160917.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160918.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160920.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160921.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160922.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160923.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160924.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160925.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160926.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160927.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160928.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160929.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-160930.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161001.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161002.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161003.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161004.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161005.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161006.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161007.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161008.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161009.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161010.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161011.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161012.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161013.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161014.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161015.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161016.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161017.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161018.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161019.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161020.log
# D:/geocosmo/cosmetecor data/s10-imfset\S10-Tula-161021.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161029.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161030.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161031.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161101.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161102.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161103.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161104.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161105.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161106.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161110.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161115.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161116.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161117.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161118.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161119.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161120.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161121.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161122.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161123.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161124.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161125.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161126.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161127.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161128.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161129.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161130.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161201.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161210.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161211.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161212.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161213.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161214.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161215.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161216.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161217.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161218.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161219.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161220.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161221.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161222.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161223.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161224.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161225.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161226.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161227.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161228.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161229.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161230.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-161231.log
# D:/geocosmo/cosmetecor data/s10-imfset2017.csv
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170104.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170105.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170116.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170117.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170118.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170119.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170120.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170121.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170122.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170123.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170124.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170125.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170126.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170127.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170128.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170129.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170130.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170131.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170201.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170202.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170203.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170204.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170205.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170206.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170207.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170208.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170209.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170210.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170211.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170212.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170213.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170214.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170215.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170216.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170217.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170218.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170219.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170220.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170221.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170222.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170223.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170224.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170225.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170226.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170227.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170228.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170301.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170302.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170303.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170304.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170305.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170306.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170307.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170308.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170309.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170310.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170311.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170312.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170313.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170314.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170315.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170316.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170317.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170318.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170319.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170320.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170321.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170322.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170323.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170324.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170325.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170326.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170327.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170328.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170329.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170330.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170331.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170401.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170402.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170403.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170404.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170405.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170406.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170407.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170408.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170409.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170410.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170411.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170412.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170413.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170414.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170415.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170416.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170417.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170418.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170419.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170420.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170421.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170422.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170423.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170424.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170425.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170426.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170427.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170428.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170429.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170430.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170501.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170502.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170503.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170504.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170505.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170506.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170507.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170508.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170509.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170510.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170511.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170512.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170513.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170514.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170515.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170516.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170517.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170518.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170519.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170520.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170521.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170522.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170523.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170524.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170525.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170526.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170527.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170528.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170529.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170530.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170531.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170601.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170602.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170603.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170604.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170605.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170606.log
# D:/geocosmo/cosmetecor data/s10-imfset\s10-tula-170607.log

# %% [markdown]
# ## Create the HDF5 File
#
# HDF5 file format allows us to create groups and datasets. Groups are similar to folders and datasets are essentially numpy arrays.
#
# The code below takes the datetime and the EMF data in the .csv files (consolidated by year) and write them into datasets (timestamp and emf_data) organized by groups (year) in the .h5 file.
#
# Take the Station 6 Chieti dataset as an example, the code takes the following yearly .csv files and write them into a single .h5 file 's6-chieti_emf.h5':
#
# * s6-chieti2017.csv
# * s6-chieti2016.csv
# * s6-chieti2015.csv
# * s6-chieti2014.csv
# * s6-chieti2013.csv
#
# Inside the .h5 file, there will be 5 groups each corresponding to a year of data:
#
# * 2017
# * 2016
# * 2015
# * 2014
# * 2013
#
# Within each group will be 2 datasets:
#
# * timestamp - an 1-dim array of UNIX timestamp corresponding to the datetime of the EMF data (dtype = int)
# * emf_data - a 28/32-dim array of EMF data (dtype = float32)
#
# The code also do some basic data cleaning:
# * If the number of columns are not as expected (most .LOG files contain 32 columns of EMF data, but some contains only 28), the code will print out the row of data with the mismatched column numbers and exit
# * If the number of columns are matched, but there are missing data (usually empty string ''), the code will convert the empty string to NaN

# %%
import csv

# This is a simple code to figure out the column number of the .csv files you are
# converting to .h file
with open('D:/geocosmo/cosmetecor data/s10-imfset2016.csv', 'rb') as f:
    reader = csv.reader(f, delimiter=' ')
    i = 0
    for row in reader:
        i += 1
        if i is 1:
            print "There are %d items per row of data" %len(row) 
            
        if i < 5:
            print row   # Print first 5 rows
            
        if i > 10:
            break
               
f.close()
# Out:
# There are 34 items per row of data
# ['2016.07.29', '13:06:03', '86.478', '67.766', '157.691', '-38.551', '114.951', '52.613', '167.021', '198.571', '-0.653', '197.305', '0.900', '45.528', '39.628', '44.465', '40.716', '43.188', '148.871', '1.305', '149.238', '1.049', '147.041', '4.402', '151.723', '156.811', '0.861', '165.937', '0.597', '9.739', '10.280', '18.180', '18.169', '18.728']
# ['2016.07.29', '13:06:04', '84.184', '67.779', '155.390', '-38.542', '112.687', '52.578', '164.706', '196.227', '-0.659', '194.875', '0.884', '45.462', '39.548', '44.306', '40.566', '43.035', '151.294', '1.325', '151.658', '1.061', '149.432', '4.470', '154.192', '159.334', '0.863', '168.620', '0.606', '9.906', '10.447', '18.473', '18.462', '19.034']
# ['2016.07.29', '13:06:05', '95.049', '67.691', '166.269', '-38.604', '123.399', '52.852', '175.724', '207.481', '-0.622', '206.655', '0.877', '45.983', '40.126', '45.315', '41.576', '44.061', '149.973', '1.331', '150.334', '1.055', '148.126', '4.435', '152.835', '157.953', '0.868', '167.166', '0.608', '9.819', '10.361', '18.319', '18.305', '18.868']
# ['2016.07.29', '13:06:06', '98.860', '67.652', '170.093', '-38.623', '127.187', '52.931', '179.573', '211.460', '-0.596', '210.817', '0.882', '46.189', '40.321', '45.697', '41.943', '44.448', '150.911', '1.335', '151.270', '1.065', '149.049', '4.472', '153.783', '158.923', '0.879', '168.185', '0.608', '9.870', '10.414', '18.401', '18.384', '18.958']

# %%
import h5py
import sys
from data_util.data_analyze import *
from datetime import datetime
import calendar

#years = [2013,2014,2015,2016,2017]
#h5_filename = 'D:/geocosmo/cosmetecor data/s1-imfset_emf.h5'
#csv_filename_header = 'D:\geocosmo\cosmetecor data\s1-imfset'
# NUM_COLUMN = 32

#years = [2012,2013,2014,2015,2016,2017]
#h5_filename = 'D:/geocosmo/cosmetecor data/s1-desp-pk_emf.h5'
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s1-desp-pk'
#NUM_COLUMN = 32

#years = [2012,2013,2014,2015,2016,2017]
#h5_filename = 'D:/geocosmo/cosmetecor data/s1-desp-uz_emf.h5'
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s1-desp-uz'
#NUM_COLUMN = 26

#years = [2012,2013,2014,2015,2016,2017]
#h5_filename = 'D:/geocosmo/cosmetecor data/s2-imfset_emf.h5'
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s2-imfset'
#NUM_COLUMN = 28

#years = [2012,2013,2014,2015,2016,2017]
#h5_filename = 'D:/geocosmo/cosmetecor data/s3-imfset_emf.h5'
#csv_filename_header = 'D:\geocosmo\cosmetecor data\s3-imfset'
#NUM_COLUMN = 32

#years = [2012,2013,2014,2015,2016]
#h5_filename = 'D:/geocosmo/cosmetecor data/s4-esso_emf.h5'
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s4-esso'
#NUM_COLUMN = 28

#years = [2013,2014,2015,2016,2017]
#h5_filename = 'D:/geocosmo/cosmetecor data/s5-altai_emf.h5'
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s5-altai'
#NUM_COLUMN = 32

#years = [2013,2014,2015,2016,2017]
#h5_filename = 'D:/geocosmo/cosmetecor data/s7-imfset_emf.h5'
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s7-imfset'
#NUM_COLUMN = 32

#years = [2014,2015,2016,2017]
#h5_filename = 'D:/geocosmo/cosmetecor data/s8-imfset_emf.h5'
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s8-imfset'
#NUM_COLUMN = 32

#years = [2015,2016,2017]
#h5_filename = 'D:/geocosmo/cosmetecor data/s9-imfset_emf.h5'
#csv_filename_header = 'D:/geocosmo/cosmetecor data/s9-imfset'
#NUM_COLUMN = 32

years = [2016,2017]
h5_filename = 'D:/geocosmo/cosmetecor data/s10-imfset_emf.h5'
csv_filename_header = 'D:/geocosmo/cosmetecor data/s10-imfset'
NUM_COLUMN = 32

fout = h5py.File (h5_filename, 'w')

for year in years:
    filename = csv_filename_header+str(year)+'.csv'
    print filename
    
    # Count the number of rows of data
    print "Number of rows of data in %s:" % filename
    start = time.time()
    num = num_datapoints(filename,dict=False)
    end = time.time()
    print num
    print "Seconds taken is %.2f" % (end-start)

    # Create the arrays in memory to hold them
    # X - to hold the EMF measurements
    X = np.zeros((NUM_COLUMN,num), dtype=np.float32)
    print X.shape
    num_bytes = sys.getsizeof(X)
    print "Memory used for numpy array = %d bytes" % num_bytes

    # Timestamp - to hold the UNIX timestamp of the EMF data
    TimeStamp = np.zeros((1,num), dtype= 'int')
    print TimeStamp.shape
    num_bytes = sys.getsizeof(TimeStamp)
    print "Memory used for numpy array = %d bytes" % num_bytes

    # Transfer data from .csv file to memory
    start = time.time()
    with open(filename, 'rb') as f:
        reader = csv.reader(f, delimiter=' ')
        idx=0
        for row in reader:
            dt = datetime.strptime(row[0]+' '+row[1], "%Y.%m.%d %H:%M:%S")
            TimeStamp[0,idx] = datatime_2_timestamp(dt,utc=True)
            
            # This try-except statement identifies LOG files which do not contain the expected number of columns
            # of EMF data.
            try:
                for i, x in enumerate(row):
                    if x == '':
                        row[i] = np.NaN    # Replace any empty string '' with NaN
                X[:,idx] = row[2:NUM_COLUMN+2]
            except ValueError:
                print row
                fout.close()
                raise
            if idx < 2:     # Print out the first 2 rows
                print row
                print X
                print TimeStamp
            idx += 1
    f.close()
    end = time.time()
    print "Time to access the csv file to transfer %d column of data: %.2f" % (NUM_COLUMN,end-start)

    # Transfer data from memory to the datasets in .h5 file
    print "Time to write to the HDF5 file:"
    start = time.time()
    dset_name = str(year)+'/emf_data'
    tset_name = str(year)+'/timestamp'
    emf_data = fout.create_dataset(dset_name,(NUM_COLUMN,num), dtype="float32")
    emf_data[...] = X
    timestamp = fout.create_dataset(tset_name,(1,num), dtype="int")
    timestamp[...] = TimeStamp
    end = time.time()
    print end-start

fout.close()

# Release memory
TimeStamp = np.zeros((1,10), dtype= 'int')
X = np.zeros((NUM_COLUMN,10), dtype=np.float32)
# Out:
# D:/geocosmo/cosmetecor data/s10-imfset2016.csv
# Number of rows of data in D:/geocosmo/cosmetecor data/s10-imfset2016.csv:
# 10731323
# Seconds taken is 33.89
# (32L, 10731323L)
# Memory used for numpy array = 1373609456 bytes
# (1L, 10731323L)
# Memory used for numpy array = 42925404 bytes
# ['2016.07.29', '13:06:03', '86.478', '67.766', '157.691', '-38.551', '114.951', '52.613', '167.021', '198.571', '-0.653', '197.305', '0.900', '45.528', '39.628', '44.465', '40.716', '43.188', '148.871', '1.305', '149.238', '1.049', '147.041', '4.402', '151.723', '156.811', '0.861', '165.937', '0.597', '9.739', '10.280', '18.180', '18.169', '18.728']
# [[  86.47799683    0.            0.         ...,    0.            0.            0.        ]
#  [  67.76599884    0.            0.         ...,    0.            0.            0.        ]
#  [ 157.69099426    0.            0.         ...,    0.            0.            0.        ]
#  ...,
#  [  18.18000031    0.            0.         ...,    0.            0.            0.        ]
#  [  18.16900063    0.            0.         ...,    0.            0.            0.        ]
#  [  18.72800064    0.            0.         ...,    0.            0.            0.        ]]
# [[1469797563          0          0 ...,          0          0          0]]
# ['2016.07.29', '13:06:04', '84.184', '67.779', '155.390', '-38.542', '112.687', '52.578', '164.706', '196.227', '-0.659', '194.875', '0.884', '45.462', '39.548', '44.306', '40.566', '43.035', '151.294', '1.325', '151.658', '1.061', '149.432', '4.470', '154.192', '159.334', '0.863', '168.620', '0.606', '9.906', '10.447', '18.473', '18.462', '19.034']
# [[  86.47799683   84.18399811    0.         ...,    0.            0.            0.        ]
#  [  67.76599884   67.77899933    0.         ...,    0.            0.            0.        ]
#  [ 157.69099426  155.38999939    0.         ...,    0.            0.            0.        ]
#  ...,
#  [  18.18000031   18.47299957    0.         ...,    0.            0.            0.        ]
#  [  18.16900063   18.46199989    0.         ...,    0.            0.            0.        ]
#  [  18.72800064   19.0340004     0.         ...,    0.            0.            0.        ]]
# [[1469797563 1469797564          0 ...,          0          0          0]]
# Time to access the csv file to transfer 32 column of data: 412.62
# Time to write to the HDF5 file:
# 16.9609999657
# D:/geocosmo/cosmetecor data/s10-imfset2017.csv
# Number of rows of data in D:/geocosmo/cosmetecor data/s10-imfset2017.csv:
# 12492040
# Seconds taken is 36.65
# (32L, 12492040L)
# Memory used for numpy array = 1598981232 bytes
# (1L, 12492040L)
# Memory used for numpy array = 49968272 bytes
# ['2017.01.04', '09:48:53', '25.771', '79.538', '107.341', '-23.226', '80.965', '27.197', '106.689', '119.430', '2.793', '123.690', '2.882', '15.290', '12.988', '20.722', '18.520', '18.160', '69.087', '0.800', '69.214', '0.733', '68.197', '1.958', '70.190', '71.514', '0.627', '74.024', '0.642', '3.559', '3.743', '5.928', '5.921', '6.135']
# [[  25.77099991    0.            0.         ...,    0.            0.            0.        ]
#  [  79.53800201    0.            0.         ...,    0.            0.            0.        ]
#  [ 107.34100342    0.            0.         ...,    0.            0.            0.        ]
#  ...,
#  [   5.92799997    0.            0.         ...,    0.            0.            0.        ]
#  [   5.921         0.            0.         ...,    0.            0.            0.        ]
#  [   6.13500023    0.            0.         ...,    0.            0.            0.        ]]
# [[1483523333          0          0 ...,          0          0          0]]
# ['2017.01.04', '09:48:54', '29.211', '79.510', '110.788', '-23.233', '84.377', '27.244', '110.158', '122.968', '2.804', '127.364', '2.882', '15.430', '13.139', '20.978', '18.778', '18.427', '73.585', '0.834', '73.732', '0.757', '72.656', '2.061', '74.765', '76.138', '0.646', '78.778', '0.645', '3.743', '3.940', '6.235', '6.234', '6.471']
# [[  25.77099991   29.21100044    0.         ...,    0.            0.            0.        ]
#  [  79.53800201   79.51000214    0.         ...,    0.            0.            0.        ]
#  [ 107.34100342  110.78800201    0.         ...,    0.            0.            0.        ]
#  ...,
#  [   5.92799997    6.23500013    0.         ...,    0.            0.            0.        ]
#  [   5.921         6.23400021    0.         ...,    0.            0.            0.        ]
#  [   6.13500023    6.47100019    0.         ...,    0.            0.            0.        ]]
# [[1483523333 1483523334          0 ...,          0          0          0]]
# Time to access the csv file to transfer 32 column of data: 482.15
# Time to write to the HDF5 file:
# 20.2760000229

# %% [markdown]
# ## Print Some Data

# %%
def printname(name):
    print name

file = h5py.File ('D:/geocosmo/cosmetecor data/s1-desp-pk_emf.h5', 'r')

# Explore group and datasets in the hdf5 file
file.visit(printname)
print file['2017/timestamp'].shape
print file['2017/emf_data'].shape

# print some data in dataset
dset = file['2017/emf_data'][:,10:15]
print dset

tset = file['2017/timestamp'][:,10:15]
print tset

file.close()
# Out:
# 2012
# 2012/emf_data
# 2012/timestamp
# 2013
# 2013/emf_data
# 2013/timestamp
# 2014
# 2014/emf_data
# 2014/timestamp
# 2015
# 2015/emf_data
# 2015/timestamp
# 2016
# 2016/emf_data
# 2016/timestamp
# 2017
# 2017/emf_data
# 2017/timestamp
# (1, 12066580)
# (32, 12066580)
# [[  -8.74499989   -8.74400043   -8.74300003   -8.74199963   -8.74199963]
#  [-205.10499573 -205.10499573 -205.10499573 -205.10400391 -205.10400391]
#  [-213.44799805 -213.44700623 -213.44700623 -213.44599915 -213.44500732]
#  [  69.77300262   69.77300262   69.77300262   69.77300262   69.77200317]
#  [-143.02099609 -143.02000427 -143.02000427 -143.01899719 -143.01899719]
#  [  46.2140007    46.2140007    46.2140007    46.21300125   46.21300125]
#  [ -93.57099915  -93.56999969  -93.56999969  -93.56900024  -93.56800079]
#  [-133.09700012 -133.09700012 -133.09599304 -133.09599304 -133.09599304]
#  [-224.11300659 -224.11199951 -224.11099243 -224.11000061 -224.10899353]
#  [  -0.98900002   -0.98900002   -0.98900002   -0.99000001   -0.99000001]
#  [-224.35600281 -224.35600281 -224.35499573 -224.35499573 -224.35400391]
#  [  74.69000244   74.69100189   74.69300079   74.69499969   74.6969986 ]
#  [ -83.77400208  -83.77400208  -83.77500153  -83.77600098  -83.77600098]
#  [-293.5710144  -293.57199097 -293.57299805 -293.57400513 -293.57501221]
#  [-223.47200012 -223.4730072  -223.47399902 -223.4750061  -223.47599792]
#  [-176.32400513 -176.32499695 -176.32600403 -176.32699585 -176.32899475]
#  [  38.49900055   38.50699997   38.51499939   38.52399826   38.5320015 ]
#  [  68.75499725   68.79000092   68.82700348   68.86599731   68.90699768]
#  [ 102.63700104  102.67900085  102.72499847  102.77200317  102.82299805]
#  [  43.88800049   43.9090004    43.93199921   43.95500183   43.97900009]
#  [  57.56999969   57.59400177   57.61999893   57.64799881   57.67699814]
#  [  24.92399979   24.93300056   24.94199944   24.95100021   24.96100044]
#  [  34.0870018    34.10200119   34.11800003   34.13499832   34.15399933]
#  [  74.18000031   74.20600128   74.23300171   74.26200104   74.29199982]
#  [ 103.76200104  103.79699707  103.83399963  103.87400055  103.91600037]
#  [  42.96699905   42.97999954   42.99399948   43.00799942   43.02099991]
#  [  68.39199829   68.42299652   68.45700073   68.4940033    68.53299713]
#  [  61.13199997   61.13800049   61.14500046   61.15299988   61.1609993 ]
#  [  25.97599983   25.97299957   25.96899986   25.9659996    25.96299934]
#  [  45.52399826   45.55099869   45.58000183   45.61100006   45.64400101]
#  [  21.62700081   21.62999916   21.62999916   21.62999916   21.62800026]
#  [  29.86400032   29.86199951   29.8579998    29.85400009   29.84799957]]
# [[1483228811 1483228812 1483228813 1483228814 1483228815]]

# %% [markdown]
# ## Check Data Integrity
#
# This makes sure that the EMF and timing data are not corrupted when converting from .csv files to .h5 groups and datasets.
#
# THe code select 3 random row in the .csv file. Print out their content. It then goes to the .h5 file and get the corresponding 3 rows from the group/dataset.
#
# It then performs a matrix subtraction of the 3 rows in the .h5 file from the 3 rows in the .csv, and print out the difference. It should be very small.

# %%
import random
import csv
from data_util.data_analyze import *
from datetime import datetime

#filename = 'D:\geocosmo\cosmetecor data\s1-desp-uz2013.csv'
#h5_filename = 'D:\geocosmo\cosmetecor data\s1-desp-uz_emf.h5'
#h5_timestamp = '2013/timestamp'
#h5_emf = '2013/emf_data'
#NUM_COLUMNS = 26   # Make sure the number of columns of EMF data is correct!!!

#filename = 'D:\geocosmo\cosmetecor data\s4-esso2013.csv'
#h5_filename = 'D:\geocosmo\cosmetecor data\s4-esso_emf.h5'
#h5_timestamp = '2013/timestamp'
#h5_emf = '2013/emf_data'
#NUM_COLUMNS = 28   # Make sure the number of columns of EMF data is correct!!!

#filename = 'D:\geocosmo\cosmetecor data\s5-altai2013.csv'
#h5_filename = 'D:\geocosmo\cosmetecor data\s5-altai_emf.h5'
#h5_timestamp = '2013/timestamp'
#h5_emf = '2013/emf_data'
#NUM_COLUMNS = 32   # Make sure the number of columns of EMF data is correct!!!

filename = 'D:\geocosmo\cosmetecor data\s7-imfset2013.csv'
h5_filename = 'D:\geocosmo\cosmetecor data\s7-imfset_emf.h5'
h5_timestamp = '2013/timestamp'
h5_emf = '2013/emf_data'
NUM_COLUMNS = 32   # Make sure the number of columns of EMF data is correct!!!

# Count number of rows in .csv file
print "Number of rows of data in %s:" % filename
num = num_datapoints(filename,dict=False)
print num

# Randomly select 3 rows in a .csv file (a year of EMF data)
random_rows = []
random_rows =sorted(random.sample(xrange(num),3))

Timestamps = []
EMFs = np.zeros((NUM_COLUMNS,3))

f = open(filename, 'r')
reader = csv.reader(f, delimiter=' ')

print "3 random rows chosen from .csv file:"
j=0
for i, row in enumerate(reader):
    if i in random_rows:
        print "%s\n" %(row[0]+' '+row[1])
        dt = datetime.strptime(row[0]+' '+row[1], "%Y.%m.%d %H:%M:%S")
        Timestamps.append(datatime_2_timestamp(dt,utc=True))
        # This try-except statement identifies a row with unexpected data
        try:
            EMFs[:,j] =row[2:NUM_COLUMNS+2]
        except ValueError:
            print row
            fout.close()
        j += 1

f.close()

print Timestamps
print EMFs

def index(array, item):
    for idx, val in np.ndenumerate(array):
        if val == item:
            return idx
 
# Access the same 3 rows in the .h5 file

file = h5py.File (h5_filename, 'r')
h5_EMFs = np.zeros((NUM_COLUMNS,3))

print file[h5_timestamp].shape
print file[h5_timestamp].dtype

for i, time in enumerate(Timestamps):
    idx = index(file[h5_timestamp],time)
    h5_EMFs[:,i] = file[h5_emf][:,idx[1]]

file.close()

print "The same 3 rows chosen in the .h5 file:"
print h5_EMFs

diff = np.sum(h5_EMFs - EMFs)
print ("The difference between the random data: ", diff)
# Out:
# Number of rows of data in D:\geocosmo\cosmetecor data\s7-imfset2013.csv:
# 17949860
# 3 random rows chosen from .csv file:
# 2013.06.20 10:44:55
#
# 2013.08.25 09:27:01
#
# 2013.12.28 02:55:51
#
# [1371725095, 1377422821, 1388199351]
# [[ -1.55091000e+02  -1.02426000e+02  -1.24179000e+02]
#  [ -5.28580000e+01  -5.10180000e+01  -5.15780000e+01]
#  [ -2.08149000e+02  -1.53158000e+02  -1.75923000e+02]
#  [ -5.35290000e+01  -5.33410000e+01  -6.59030000e+01]
#  [ -2.62097000e+02  -2.06638000e+02  -2.42123000e+02]
#  [  3.26100000e+00  -1.89000000e-01   8.42300000e+00]
#  [ -2.59377000e+02  -2.07007000e+02  -2.34122000e+02]
#  [ -2.23416000e+02  -1.75658000e+02  -1.85784000e+02]
#  [ -3.00280000e+01   8.49000000e+00   1.43450000e+01]
#  [ -6.09140000e+01  -1.26766000e+02  -1.64375000e+02]
#  [  1.39920000e+01   3.09670000e+01   8.70320000e+01]
#  [ -1.49950000e+01  -2.22710000e+01  -9.59600000e+00]
#  [ -3.05060000e+01  -4.56270000e+01  -4.08230000e+01]
#  [  1.47708000e+02   3.12270000e+01   1.90510000e+01]
#  [  1.65299000e+02   6.94130000e+01   1.11151000e+02]
#  [  2.12608000e+02   1.93391000e+02   1.11651000e+02]
#  [  3.54650000e+01   7.12060000e+01   3.18260000e+01]
#  [  1.43600000e+00   1.43400000e+00   7.21000000e-01]
#  [  3.64920000e+01   7.25000000e+01   3.21470000e+01]
#  [  1.29600000e+00   1.06200000e+00   4.92000000e-01]
#  [  3.73410000e+01   7.34100000e+01   3.24160000e+01]
#  [  1.35600000e+00   9.82000000e-01   6.40000000e-01]
#  [  3.79320000e+01   7.41020000e+01   3.24550000e+01]
#  [  2.38180000e+01   5.72520000e+01   2.37230000e+01]
#  [  9.67000000e-01   8.02000000e-01   6.84000000e-01]
#  [  2.01190000e+01   5.61710000e+01   2.35990000e+01]
#  [  2.40100000e+00   1.65670000e+01   6.79400000e+00]
#  [  3.18800000e+01   1.84430000e+01   2.22780000e+01]
#  [  3.27970000e+01   1.71330000e+01   2.22450000e+01]
#  [  3.95380000e+01   3.19440000e+01   3.71140000e+01]
#  [  3.96730000e+01   3.16480000e+01   3.80850000e+01]
#  [  4.39100000e+01   2.92960000e+01   2.88410000e+01]]
# (1, 17949860)
# int32
# The same 3 rows chosen in the .h5 file:
# [[ -1.55091003e+02  -1.02426003e+02  -1.24179001e+02]
#  [ -5.28580017e+01  -5.10180016e+01  -5.15779991e+01]
#  [ -2.08149002e+02  -1.53158005e+02  -1.75923004e+02]
#  [ -5.35289993e+01  -5.33409996e+01  -6.59029999e+01]
#  [ -2.62096985e+02  -2.06638000e+02  -2.42123001e+02]
#  [  3.26099992e+00  -1.88999996e-01   8.42300034e+00]
#  [ -2.59377014e+02  -2.07007004e+02  -2.34121994e+02]
#  [ -2.23416000e+02  -1.75658005e+02  -1.85783997e+02]
#  [ -3.00279999e+01   8.48999977e+00   1.43450003e+01]
#  [ -6.09140015e+01  -1.26765999e+02  -1.64375000e+02]
#  [  1.39919996e+01   3.09669991e+01   8.70319977e+01]
#  [ -1.49949999e+01  -2.22709999e+01  -9.59599972e+00]
#  [ -3.05060005e+01  -4.56269989e+01  -4.08230019e+01]
#  [  1.47707993e+02   3.12269993e+01   1.90510006e+01]
#  [  1.65298996e+02   6.94130020e+01   1.11151001e+02]
#  [  2.12608002e+02   1.93391006e+02   1.11651001e+02]
#  [  3.54650002e+01   7.12060013e+01   3.18260002e+01]
#  [  1.43599999e+00   1.43400002e+00   7.21000016e-01]
#  [  3.64920006e+01   7.25000000e+01   3.21469994e+01]
#  [  1.29600000e+00   1.06200004e+00   4.92000014e-01]
#  [  3.73409996e+01   7.34100037e+01   3.24160004e+01]
#  [  1.35599995e+00   9.81999993e-01   6.39999986e-01]
#  [  3.79319992e+01   7.41019974e+01   3.24550018e+01]
#  [  2.38180008e+01   5.72519989e+01   2.37229996e+01]
#  [  9.67000008e-01   8.01999986e-01   6.84000015e-01]
#  [  2.01189995e+01   5.61710014e+01   2.35990009e+01]
#  [  2.40100002e+00   1.65669994e+01   6.79400015e+00]
#  [  3.18799992e+01   1.84430008e+01   2.22779999e+01]
#  [  3.27970009e+01   1.71329994e+01   2.22450008e+01]
#  [  3.95379982e+01   3.19440002e+01   3.71139984e+01]
#  [  3.96730003e+01   3.16480007e+01   3.80849991e+01]
#  [  4.39099998e+01   2.92959995e+01   2.88409996e+01]]
# ('The difference between the random data: ', -2.1534085249463875e-05)

# %% [markdown]
# ## Some Useful Code
#
# The cells below are handy in case files are not closed, or resources are not released.

# %%
file.close()

# %%
TimeStamp = np.zeros((1,10), dtype= 'int')
X = np.zeros((NUM_COLUMN,10), dtype=np.float32)

# %%
ftp.quit()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-b1f3b38000de> in <module>()
# ----> 1 ftp.quit()
#
# C:\ProgramData\Anaconda2\lib\ftplib.pyc in quit(self)
#     589     def quit(self):
#     590         '''Quit, and close the connection.'''
# --> 591         resp = self.voidcmd('QUIT')
#     592         self.close()
#     593         return resp
#
# C:\ProgramData\Anaconda2\lib\ftplib.pyc in voidcmd(self, cmd)
#     251     def voidcmd(self, cmd):
#     252         """Send a command and expect a response beginning with '2'."""
# --> 253         self.putcmd(cmd)
#     254         return self.voidresp()
#     255
#
# C:\ProgramData\Anaconda2\lib\ftplib.pyc in putcmd(self, line)
#     179     def putcmd(self, line):
#     180         if self.debugging: print '*cmd*', self.sanitize(line)
# --> 181         self.putline(line)
#     182
#     183     # Internal: return one line from the server, stripping CRLF.
#
# C:\ProgramData\Anaconda2\lib\ftplib.pyc in putline(self, line)
#     174         line = line + CRLF
#     175         if self.debugging > 1: print '*put*', self.sanitize(line)
# --> 176         self.sock.sendall(line)
#     177
#     178     # Internal: send one command to the server (through putline())
#
# C:\ProgramData\Anaconda2\lib\socket.pyc in meth(name, self, *args)
#     226
#     227 def meth(name,self,*args):
# --> 228     return getattr(self._sock,name)(*args)
#     229
#     230 for _m in _socketmethods:
#
# error: [Errno 10054] An existing connection was forcibly closed by the remote host

# %%
dFile.close()

# %%
fout.close()
